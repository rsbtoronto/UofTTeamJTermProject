# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.options.mode.chained_assignment = None

# %%
data = pd.read_excel('DataFileAssignment.xls')
data = data[(data.Year < '2011-12-31')]
data.index=data['Year']
data.drop('Year', axis=1, inplace=True)
data.tail()
# Out:
#              Country   Total Pop   Pop Male  Pop Female  Transportation All  \
# Year
# 2006-12-31  ZIMBABWE  13182000.0  6788730.0   6393270.0                 NaN
# 2007-12-31  ZIMBABWE  13380000.0  6890700.0   6489300.0                 NaN
# 2008-12-31  ZIMBABWE  13578000.0  6992670.0   6585330.0                 NaN
# 2009-12-31  ZIMBABWE  13776000.0  7094640.0   6681360.0                 NaN
# 2010-12-31  ZIMBABWE  13974000.0  7196610.0   6777390.0                 NaN
#
#             Transportation Male  Transportation Female  Falls All  Falls Male  \
# Year
# 2006-12-31                  NaN                    NaN        NaN         NaN
# 2007-12-31                  NaN                    NaN        NaN         NaN
# 2008-12-31                  NaN                    NaN        NaN         NaN
# 2009-12-31                  NaN                    NaN        NaN         NaN
# 2010-12-31                  NaN                    NaN        NaN         NaN
#
# ...

# %% [markdown]
# # Trending by Type of Fatality

# %%
a['Pop Male'] = data.groupby(['Year'])['Pop Male'].transform('sum')
a['Pop Female'] = data.groupby(['Year'])['Pop Female'].transform('sum')
a['Pop All'] = data.groupby(['Year'])['Total Pop'].transform('sum')
plt.title("Figure #0 Transportation Fatalities")
plt.plot(a['Pop Male'])
plt.plot(a['Pop Female'])
plt.plot(a['Pop All'])
plt.show()

# %%
a['Transportation Male'] = data.groupby(['Year'])['Transportation Male'].transform('sum')
a['Transportation Female'] = data.groupby(['Year'])['Transportation Female'].transform('sum')
a['Transportation All'] = data.groupby(['Year'])['Transportation All'].transform('sum')
plt.title("Figure #1 Transportation Fatalities")
plt.plot(a['Transportation Male'])
plt.plot(a['Transportation Female'])
plt.plot(a['Transportation All'])
plt.show()

# %%
a['Falls Male'] = data.groupby(['Year'])['Falls Male'].transform('sum')
a['Falls Female'] = data.groupby(['Year'])['Falls Female'].transform('sum')
a['Falls All'] = data.groupby(['Year'])['Falls All'].transform('sum')
plt.title("Figure #2 Fall Fatalities")
plt.plot(a['Falls Male'])
plt.plot(a['Falls Female'])
plt.plot(a['Falls All'])
plt.show()

# %%
a['Murdered Male'] = data.groupby(['Year'])['Murdered Male'].transform('sum')
a['Murdered Female'] = data.groupby(['Year'])['Murdered Female'].transform('sum')
a['Murdered All'] = data.groupby(['Year'])['Murdered All'].transform('sum')
plt.title("Figure #3 Murder Fatalities")

plt.plot(a['Murdered Male'])
plt.plot(a['Murdered Female'])
plt.plot(a['Murdered All'])
plt.show()

# %%
a['Suicide Male'] = data.groupby(['Year'])['Suicide Male'].transform('sum')
a['Suicide Female'] = data.groupby(['Year'])['Suicide Female'].transform('sum')
a['Suicide All'] = data.groupby(['Year'])['Suicide All'].transform('sum')
plt.title("Figure #4 Suicide Fatalities")
plt.plot(a['Suicide Male'])
plt.plot(a['Suicide Female'])
plt.plot(a['Suicide All'])
plt.show()

# %%
a['Other Male'] = data.groupby(['Year'])['Other Male'].transform('sum')
a['Other Female'] = data.groupby(['Year'])['Other Female'].transform('sum')
a['Other All'] = data.groupby(['Year'])['Other All'].transform('sum')
plt.title("Figure #5 Transportation Fatalities")

plt.plot(a['Other Male'])
plt.plot(a['Other Female'])
plt.plot(a['Other All'])
plt.show()
